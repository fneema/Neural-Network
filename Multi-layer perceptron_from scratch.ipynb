# %%
#Importing libraries
import torch
import math

# %% [markdown]
# **The objective here is to implement a multi-layer perceptron with one hidden layer from scratch and test it on MNIST.**

# %% [markdown]
# **Activation function**

# %% [markdown]
# - We create two functions, sigma and its derivative.
# - The sigma function will be applied to data for non-linear transformation.
# - We need the derivative function of sigma in calculating backward propagation.

# %%
#Function to calculate the activation value i.e tanh
def sigma(x):
     return torch.tanh(x)

#Function to calculate derivative of activation function i.e tanh
def dsigma(x):
    return 1-(sigma(x))**2

# %% [markdown]
# **Loss**

# %% [markdown]
# - Here we calculate loss, where we sum the square difference of the predicted values of the target (v) and the actual values of the target (t).
# - The loss is defined as: $||t-v||^2 = \sum (t-v)^2$.
# - We also calculated the derivative of the of the loss which will help us get calculating the backward propagation.

# %%
#Function to calculate loss of a function
def loss(v,t):
    return (v - t).pow(2).sum()

#Function to calculate derivative of the loss function
def dloss(v,t):
    return 2*(v-t)

# %% [markdown]
# **Forward and backward passes**

# %% [markdown]
# - Here, we define a forward function, which takes the inputs, and the weigth and bias of two layers. This function computes forward pass in the network.
# - For each neuron present in the network, forward pass involves two steps:
#
# 1.  Pre-activation represented by 's': it is a weighted sum of inputs (w and x) plus bias (b).
# - $s = w^Tx + b $
# 2. Activation represented by 'x': activation function here is tanh.
# - $\sigma(s)$
# - The activation output of the final layer is the same as the predicted value of the network i.e x2.
#
# - We also defined a backward function to calculate the back propagation. It updates the gradients of the model i.e weight and bias.

# %%
#Function for computng forward pass in the network.
def forward_pass(w1, b1, w2, b2, x):
    x0 = x
    s1 = torch.matmul(w1,x0) + b1
    x1 = sigma(s1)
    s2 =torch.matmul(w2,x1) + b2
    x2 = sigma(s2)

    return x0, s1, x1, s2, x2

#Function for computing backward pass in the network.
def backward_pass(w1, b1, w2, b2,
                  t,
                  x, s1, x1, s2, x2,
                  dl_dw1, dl_db1, dl_dw2, dl_db2):
    x0 = x
    dl_dx2 = dloss(x2, t)
    dl_ds2 = dsigma(s2) * dl_dx2
    dl_dx1 = torch.matmul(w2.t(),dl_dx2)

    dl_ds1 = dsigma(s1) * dl_dx1

    
    dl_dw2.add_(dl_ds2.view(-1, 1).mm(x1.view(1, -1)))
    dl_db2.add_(dl_ds2)
    dl_dw1.add_(dl_ds1.view(-1, 1).mm(x0.view(1, -1)))
    dl_db1.add_(dl_ds1)

# %% [markdown]
# **Training the network**

# %% [markdown]
# - Here we write the code to train and test the neural network with one hidden layer of 50 units.
# - The network have an input size of 784, which is the dimension of the MNIST training set, and an output size of 10, which is the number of classes.
# 1. We downloaded the data using the provided prologue.load_data function, with one-hot label vectors and normalized inputs.
# - We multiplied the target label vector by $\zeta =0.9$ (so that they are strictly in the value range of tanh).
# 2. We created four weight and bias tensors, and fill them with random values sampled according to N(0,epsilon) with epsilon = $1e^{-6}$.
# 3. We created four tensor to sum up the gradients on individual samples, with respect to weigths and biases.
#
# 4. We performed 1,000 gradiented steps aith a step size $\eta$ equal to 0.1 divided by the number of training samples.
# - Each of the above steps required to reset to zero the tensors for summing up the gradients (to avoid the gradients from recording a running tally of all the operations that had happened), and doing a forward and backward pass for each training example.
# - We computed and printed the training loss, training error and test error after every step using the class of maximum response as the predicted one.

# %%
#Loading  data
import dlc_practical_prologue as prologue
train_input, train_target, test_input, test_target = prologue.load_data(one_hot_labels = True,
                                                                        normalize = True)
#Creating the number of classes, which is 10
n_classes = train_target.size(1)
#Creating the number of training samples whish is 784
n_train_samples = train_input.size(0)


zeta = 0.90

#Multiplying zeta with training input
train_input = train_input * zeta
#Multiplying zeta with testing input
test_input = test_input * zeta


#Number of units/neurons in one hidden layer
n_hidden = 50
#Gradient step size or learning rate
eta = 1e-1 / n_train_samples

epsilon = 1e-6

#Initalizing weights and bias tensors
w1 = torch.normal(0,epsilon,size=(n_hidden, train_input.size(1)))
b1 = torch.empty(n_hidden).normal_(0, epsilon)
w2 = torch.normal(0,epsilon, size = (n_classes, n_hidden))
b2 = torch.empty(n_classes).normal_(0, epsilon)

dl_dw1 = torch.empty(w1.size())
dl_db1 = torch.empty(b1.size())
dl_dw2 = torch.empty(w2.size())
dl_db2 = torch.empty(b2.size())

#Creating loop to perform 1000 gradient steps
for k in range(1000):

    # Forwrad and backward pass

    acc_loss = 0
    n_train_errors = 0
     
    #Reseting to zero the tensors for summing up the gradients
    dl_dw1.zero_()
    dl_db1.zero_()
    dl_dw2.zero_()
    dl_db2.zero_()

    for n in range(n_train_samples):
        x0, s1, x1, s2, x2 = forward_pass(w1, b1, w2, b2, train_input[n])

        pred = x2.max(0)[1].item()
        if train_target[n, pred] < 0.5: n_train_errors = n_train_errors + 1
        acc_loss = acc_loss + loss(x2, train_target[n])

        backward_pass(w1, b1, w2, b2,
                      train_target[n],
                      x0, s1, x1, s2, x2,
                      dl_dw1, dl_db1, dl_dw2, dl_db2)

    # Gradient step, updating weights and bias

    w1 = w1 - eta * dl_dw1
    b1 = b1 - eta * dl_db1
    w2 = w2 - eta * dl_dw2
    b2 = b2 - eta * dl_db2

    # Testing errors

    n_test_errors = 0

    for n in range(test_input.size(0)):
        _, _, _, _, x2 = forward_pass(w1, b1, w2, b2, test_input[n])

        #Maximum response as the as the predicted one.
        pred = x2.max(0)[1].item()
        if test_target[n, pred] < 0.5: n_test_errors = n_test_errors + 1

    #Printing training loss, training error, and test error 
    print('{:d} acc_train_loss {:.02f} acc_train_error {:.02f}% test_error {:.02f}%'
          .format(k,
                  acc_loss,
                  (100 * n_train_errors) / train_input.size(0),
                  (100 * n_test_errors) / test_input.size(0)))
# Out:
# * Using MNIST
# ** Reduce the data-set (use --full for the full thing)
# ** Use 1000 train and 1000 test samples
# /home/aims/.local/lib/python3.7/site-packages/torchvision/datasets/mnist.py:53: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/aims/.local/lib/python3.7/site-packages/torchvision/datasets/mnist.py:43: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /home/aims/.local/lib/python3.7/site-packages/torchvision/datasets/mnist.py:58: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /home/aims/.local/lib/python3.7/site-packages/torchvision/datasets/mnist.py:48: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# 0 acc_train_loss 1000.00 acc_train_error 91.30% test_error 90.10%
# 1 acc_train_loss 963.68 acc_train_error 88.30% test_error 90.10%
# 2 acc_train_loss 940.46 acc_train_error 88.30% test_error 90.10%
# 3 acc_train_loss 925.61 acc_train_error 88.30% test_error 90.10%
# 4 acc_train_loss 916.12 acc_train_error 88.30% test_error 90.10%
# 5 acc_train_loss 910.03 acc_train_error 88.30% test_error 90.10%
# 6 acc_train_loss 906.13 acc_train_error 88.30% test_error 90.10%
# 7 acc_train_loss 903.63 acc_train_error 88.30% test_error 90.10%
# 8 acc_train_loss 902.01 acc_train_error 88.30% test_error 90.10%
# 9 acc_train_loss 900.98 acc_train_error 88.30% test_error 90.10%
# 10 acc_train_loss 900.32 acc_train_error 88.30% test_error 90.10%
# 11 acc_train_loss 899.88 acc_train_error 88.30% test_error 90.10%
# 12 acc_train_loss 899.61 acc_train_error 88.30% test_error 90.10%
# 13 acc_train_loss 899.43 acc_train_error 88.30% test_error 90.10%
# 14 acc_train_loss 899.31 acc_train_error 88.30% test_error 90.10%
# 15 acc_train_loss 899.24 acc_train_error 88.30% test_error 90.10%
# 16 acc_train_loss 899.19 acc_train_error 88.30% test_error 90.10%
# 17 acc_train_loss 899.16 acc_train_error 88.30% test_error 90.10%
# 18 acc_train_loss 899.13 acc_train_error 88.30% test_error 90.10%
# 19 acc_train_loss 899.12 acc_train_error 88.30% test_error 90.10%
# 20 acc_train_loss 899.10 acc_train_error 88.30% test_error 90.10%
# 21 acc_train_loss 899.09 acc_train_error 88.30% test_error 90.10%
# 22 acc_train_loss 899.06 acc_train_error 88.30% test_error 90.10%
# 23 acc_train_loss 899.03 acc_train_error 88.30% test_error 90.10%
# 24 acc_train_loss 898.97 acc_train_error 88.30% test_error 90.10%
# 25 acc_train_loss 898.86 acc_train_error 88.30% test_error 90.10%
# 26 acc_train_loss 898.67 acc_train_error 88.30% test_error 88.40%
# 27 acc_train_loss 898.33 acc_train_error 82.40% test_error 79.80%
# 28 acc_train_loss 897.73 acc_train_error 78.60% test_error 79.10%
# 29 acc_train_loss 896.67 acc_train_error 78.40% test_error 79.40%
# 30 acc_train_loss 894.83 acc_train_error 78.70% test_error 77.50%
# 31 acc_train_loss 891.67 acc_train_error 73.10% test_error 73.90%
# 32 acc_train_loss 886.44 acc_train_error 70.50% test_error 73.20%
# 33 acc_train_loss 878.15 acc_train_error 70.50% test_error 73.80%
# 34 acc_train_loss 865.99 acc_train_error 71.10% test_error 73.90%
# 35 acc_train_loss 849.94 acc_train_error 71.40% test_error 73.90%
# 36 acc_train_loss 831.26 acc_train_error 71.10% test_error 73.40%
# 37 acc_train_loss 812.11 acc_train_error 70.30% test_error 72.30%
# 38 acc_train_loss 794.15 acc_train_error 69.20% test_error 71.20%
# 39 acc_train_loss 778.20 acc_train_error 68.50% test_error 70.50%
# 40 acc_train_loss 765.11 acc_train_error 67.50% test_error 69.60%
# 41 acc_train_loss 755.32 acc_train_error 66.80% test_error 69.20%
# 42 acc_train_loss 747.99 acc_train_error 66.20% test_error 68.10%
# 43 acc_train_loss 741.46 acc_train_error 64.30% test_error 65.70%
# 44 acc_train_loss 734.40 acc_train_error 61.90% test_error 63.10%
# 45 acc_train_loss 726.14 acc_train_error 58.60% test_error 60.90%
# 46 acc_train_loss 716.68 acc_train_error 55.70% test_error 57.90%
# 47 acc_train_loss 706.60 acc_train_error 52.40% test_error 55.80%
# 48 acc_train_loss 696.88 acc_train_error 49.60% test_error 54.40%
# 49 acc_train_loss 688.39 acc_train_error 47.80% test_error 53.00%
# 50 acc_train_loss 681.47 acc_train_error 47.00% test_error 51.80%
# 51 acc_train_loss 675.85 acc_train_error 46.30% test_error 50.70%
# 52 acc_train_loss 670.93 acc_train_error 45.80% test_error 50.20%
# 53 acc_train_loss 666.09 acc_train_error 45.30% test_error 49.10%
# 54 acc_train_loss 660.93 acc_train_error 44.40% test_error 48.10%
# 55 acc_train_loss 655.21 acc_train_error 43.60% test_error 47.00%
# 56 acc_train_loss 648.82 acc_train_error 42.40% test_error 46.10%
# 57 acc_train_loss 641.78 acc_train_error 42.00% test_error 45.10%
# 58 acc_train_loss 634.20 acc_train_error 41.20% test_error 43.90%
# 59 acc_train_loss 626.23 acc_train_error 40.40% test_error 43.30%
# 60 acc_train_loss 618.07 acc_train_error 39.60% test_error 42.00%
# 61 acc_train_loss 609.85 acc_train_error 38.40% test_error 40.70%
# 62 acc_train_loss 601.65 acc_train_error 37.00% test_error 39.90%
# 63 acc_train_loss 593.43 acc_train_error 34.90% test_error 38.40%
# 64 acc_train_loss 585.13 acc_train_error 33.20% test_error 37.60%
# 65 acc_train_loss 576.67 acc_train_error 32.10% test_error 36.40%
# 66 acc_train_loss 568.01 acc_train_error 31.10% test_error 35.40%
# 67 acc_train_loss 559.18 acc_train_error 30.50% test_error 34.30%
# 68 acc_train_loss 550.30 acc_train_error 29.60% test_error 33.10%
# 69 acc_train_loss 541.48 acc_train_error 29.00% test_error 32.60%
# 70 acc_train_loss 532.88 acc_train_error 27.60% test_error 32.00%
# 71 acc_train_loss 524.62 acc_train_error 26.30% test_error 31.40%
# 72 acc_train_loss 516.79 acc_train_error 25.20% test_error 30.40%
# 73 acc_train_loss 509.42 acc_train_error 24.20% test_error 30.50%
# 74 acc_train_loss 502.54 acc_train_error 23.50% test_error 30.00%
# 75 acc_train_loss 496.13 acc_train_error 22.90% test_error 30.10%
# 76 acc_train_loss 490.16 acc_train_error 22.20% test_error 29.30%
# 77 acc_train_loss 484.60 acc_train_error 21.70% test_error 29.10%
# 78 acc_train_loss 479.39 acc_train_error 21.50% test_error 29.30%
# 79 acc_train_loss 474.49 acc_train_error 21.10% test_error 29.10%
# 80 acc_train_loss 469.85 acc_train_error 21.10% test_error 28.50%
# 81 acc_train_loss 465.42 acc_train_error 21.00% test_error 27.80%
# 82 acc_train_loss 461.17 acc_train_error 20.80% test_error 27.50%
# 83 acc_train_loss 457.03 acc_train_error 20.10% test_error 27.10%
# 84 acc_train_loss 452.99 acc_train_error 19.70% test_error 26.80%
# 85 acc_train_loss 448.99 acc_train_error 19.40% test_error 26.40%
# 86 acc_train_loss 445.03 acc_train_error 19.00% test_error 26.00%
# 87 acc_train_loss 441.06 acc_train_error 18.40% test_error 25.70%
# 88 acc_train_loss 437.07 acc_train_error 18.00% test_error 25.60%
# 89 acc_train_loss 433.04 acc_train_error 17.90% test_error 25.50%
# 90 acc_train_loss 428.97 acc_train_error 17.50% test_error 25.10%
# 91 acc_train_loss 424.85 acc_train_error 16.70% test_error 24.80%
# 92 acc_train_loss 420.68 acc_train_error 16.20% test_error 24.30%
# 93 acc_train_loss 416.46 acc_train_error 16.00% test_error 24.40%
# 94 acc_train_loss 412.19 acc_train_error 15.60% test_error 24.40%
# 95 acc_train_loss 407.88 acc_train_error 15.30% test_error 24.20%
# 96 acc_train_loss 403.55 acc_train_error 14.90% test_error 23.80%
# 97 acc_train_loss 399.20 acc_train_error 14.50% test_error 23.10%
# 98 acc_train_loss 394.85 acc_train_error 14.30% test_error 22.80%
# 99 acc_train_loss 390.52 acc_train_error 14.30% test_error 22.30%
# 100 acc_train_loss 386.21 acc_train_error 14.10% test_error 22.00%
# 101 acc_train_loss 381.94 acc_train_error 13.90% test_error 22.40%
# 102 acc_train_loss 377.73 acc_train_error 13.70% test_error 22.20%
# 103 acc_train_loss 373.59 acc_train_error 13.60% test_error 21.80%
# 104 acc_train_loss 369.56 acc_train_error 13.60% test_error 22.00%
# 105 acc_train_loss 365.72 acc_train_error 13.20% test_error 21.40%
# 106 acc_train_loss 362.23 acc_train_error 13.10% test_error 22.20%
# 107 acc_train_loss 359.73 acc_train_error 12.60% test_error 19.80%
# 108 acc_train_loss 359.95 acc_train_error 12.60% test_error 22.40%
# 109 acc_train_loss 367.87 acc_train_error 12.70% test_error 20.80%
# 110 acc_train_loss 396.66 acc_train_error 12.10% test_error 27.20%
# 111 acc_train_loss 454.23 acc_train_error 16.60% test_error 25.10%
# 112 acc_train_loss 512.18 acc_train_error 13.90% test_error 25.50%
# 113 acc_train_loss 426.88 acc_train_error 14.50% test_error 20.50%
# 114 acc_train_loss 374.17 acc_train_error 10.90% test_error 19.90%
# 115 acc_train_loss 361.41 acc_train_error 10.00% test_error 21.50%
# 116 acc_train_loss 367.28 acc_train_error 10.70% test_error 20.10%
# 117 acc_train_loss 378.87 acc_train_error 10.10% test_error 23.50%
# 118 acc_train_loss 392.28 acc_train_error 12.70% test_error 20.10%
# 119 acc_train_loss 389.34 acc_train_error 10.80% test_error 23.40%
# 120 acc_train_loss 371.47 acc_train_error 13.00% test_error 19.30%
# 121 acc_train_loss 352.47 acc_train_error 9.00% test_error 21.40%
# 122 acc_train_loss 342.80 acc_train_error 11.60% test_error 19.20%
# 123 acc_train_loss 340.77 acc_train_error 9.50% test_error 21.50%
# 124 acc_train_loss 348.53 acc_train_error 12.70% test_error 21.10%
# 125 acc_train_loss 363.61 acc_train_error 11.00% test_error 24.30%
# 126 acc_train_loss 384.24 acc_train_error 13.80% test_error 22.90%
# 127 acc_train_loss 390.93 acc_train_error 11.90% test_error 23.60%
# 128 acc_train_loss 373.40 acc_train_error 13.40% test_error 20.60%
# 129 acc_train_loss 349.50 acc_train_error 10.90% test_error 20.70%
# 130 acc_train_loss 336.96 acc_train_error 10.40% test_error 19.90%
# 131 acc_train_loss 331.12 acc_train_error 10.90% test_error 20.10%
# 132 acc_train_loss 330.07 acc_train_error 9.60% test_error 20.40%
# 133 acc_train_loss 331.13 acc_train_error 11.70% test_error 20.30%
# 134 acc_train_loss 332.57 acc_train_error 9.40% test_error 21.20%
# 135 acc_train_loss 335.23 acc_train_error 11.30% test_error 19.70%
# 136 acc_train_loss 335.71 acc_train_error 9.30% test_error 21.00%
# 137 acc_train_loss 336.14 acc_train_error 10.80% test_error 19.40%
# 138 acc_train_loss 333.60 acc_train_error 9.30% test_error 20.50%
# 139 acc_train_loss 330.26 acc_train_error 10.20% test_error 19.80%
# 140 acc_train_loss 325.17 acc_train_error 9.40% test_error 19.40%
# 141 acc_train_loss 319.56 acc_train_error 9.70% test_error 18.60%
# 142 acc_train_loss 314.01 acc_train_error 8.60% test_error 18.40%
# 143 acc_train_loss 308.76 acc_train_error 9.10% test_error 17.80%
# 144 acc_train_loss 304.47 acc_train_error 8.50% test_error 18.40%
# 145 acc_train_loss 300.71 acc_train_error 8.80% test_error 17.80%
# 146 acc_train_loss 297.82 acc_train_error 8.10% test_error 18.20%
# 147 acc_train_loss 295.30 acc_train_error 8.60% test_error 17.70%
# 148 acc_train_loss 293.32 acc_train_error 7.90% test_error 17.90%
# 149 acc_train_loss 291.48 acc_train_error 8.80% test_error 17.60%
# 150 acc_train_loss 289.97 acc_train_error 7.80% test_error 17.50%
# 151 acc_train_loss 288.37 acc_train_error 8.80% test_error 17.70%
# 152 acc_train_loss 286.99 acc_train_error 7.80% test_error 17.50%
# 153 acc_train_loss 285.40 acc_train_error 8.50% test_error 17.50%
# 154 acc_train_loss 284.09 acc_train_error 7.70% test_error 17.30%
# 155 acc_train_loss 282.57 acc_train_error 8.40% test_error 17.10%
# 156 acc_train_loss 281.57 acc_train_error 7.50% test_error 17.10%
# 157 acc_train_loss 280.55 acc_train_error 8.40% test_error 16.90%
# 158 acc_train_loss 280.55 acc_train_error 7.40% test_error 17.00%
# 159 acc_train_loss 280.91 acc_train_error 8.30% test_error 17.50%
# 160 acc_train_loss 283.11 acc_train_error 7.10% test_error 18.20%
# 161 acc_train_loss 286.01 acc_train_error 8.20% test_error 18.00%
# 162 acc_train_loss 291.37 acc_train_error 7.40% test_error 19.20%
# 163 acc_train_loss 296.23 acc_train_error 8.70% test_error 18.50%
# 164 acc_train_loss 301.52 acc_train_error 7.90% test_error 19.10%
# 165 acc_train_loss 301.98 acc_train_error 9.10% test_error 18.30%
# 166 acc_train_loss 299.02 acc_train_error 7.80% test_error 17.90%
# 167 acc_train_loss 291.07 acc_train_error 8.00% test_error 17.40%
# 168 acc_train_loss 282.10 acc_train_error 7.40% test_error 17.00%
# 169 acc_train_loss 273.64 acc_train_error 7.10% test_error 16.90%
# 170 acc_train_loss 266.70 acc_train_error 7.10% test_error 16.90%
# 171 acc_train_loss 261.57 acc_train_error 6.80% test_error 16.60%
# 172 acc_train_loss 257.54 acc_train_error 7.00% test_error 16.90%
# 173 acc_train_loss 254.57 acc_train_error 6.50% test_error 16.60%
# 174 acc_train_loss 252.18 acc_train_error 6.90% test_error 16.70%
# 175 acc_train_loss 250.34 acc_train_error 6.20% test_error 16.20%
# 176 acc_train_loss 248.85 acc_train_error 6.60% test_error 16.50%
# 177 acc_train_loss 247.70 acc_train_error 5.90% test_error 16.10%
# 178 acc_train_loss 246.79 acc_train_error 6.50% test_error 16.50%
# 179 acc_train_loss 246.16 acc_train_error 5.90% test_error 16.50%
# 180 acc_train_loss 245.67 acc_train_error 6.50% test_error 16.30%
# 181 acc_train_loss 245.49 acc_train_error 6.00% test_error 16.40%
# 182 acc_train_loss 245.28 acc_train_error 6.50% test_error 16.40%
# 183 acc_train_loss 245.48 acc_train_error 5.70% test_error 16.40%
# 184 acc_train_loss 245.42 acc_train_error 6.10% test_error 16.50%
# 185 acc_train_loss 245.97 acc_train_error 5.70% test_error 16.50%
# 186 acc_train_loss 246.00 acc_train_error 6.10% test_error 16.20%
# 187 acc_train_loss 247.00 acc_train_error 5.80% test_error 16.40%
# 188 acc_train_loss 247.30 acc_train_error 5.90% test_error 15.90%
# 189 acc_train_loss 249.19 acc_train_error 5.40% test_error 16.50%
# 190 acc_train_loss 250.29 acc_train_error 6.30% test_error 16.20%
# 191 acc_train_loss 253.73 acc_train_error 6.10% test_error 16.50%
# 192 acc_train_loss 256.02 acc_train_error 6.40% test_error 16.60%
# 193 acc_train_loss 260.88 acc_train_error 6.30% test_error 16.50%
# 194 acc_train_loss 263.00 acc_train_error 6.50% test_error 17.10%
# 195 acc_train_loss 266.42 acc_train_error 6.70% test_error 16.60%
# 196 acc_train_loss 264.64 acc_train_error 6.20% test_error 17.10%
# 197 acc_train_loss 262.72 acc_train_error 6.60% test_error 16.60%
# 198 acc_train_loss 256.04 acc_train_error 6.20% test_error 16.70%
# 199 acc_train_loss 250.03 acc_train_error 6.40% test_error 16.40%
# 200 acc_train_loss 242.56 acc_train_error 6.10% test_error 16.00%
# 201 acc_train_loss 236.73 acc_train_error 5.80% test_error 16.40%
# 202 acc_train_loss 231.27 acc_train_error 5.50% test_error 15.80%
# 203 acc_train_loss 227.18 acc_train_error 5.80% test_error 16.20%
# 204 acc_train_loss 223.67 acc_train_error 5.50% test_error 15.80%
# 205 acc_train_loss 220.97 acc_train_error 5.50% test_error 16.30%
# 206 acc_train_loss 218.67 acc_train_error 5.40% test_error 15.90%
# 207 acc_train_loss 216.86 acc_train_error 5.50% test_error 16.30%
# 208 acc_train_loss 215.29 acc_train_error 5.30% test_error 15.90%
# 209 acc_train_loss 214.07 acc_train_error 5.50% test_error 16.30%
# 210 acc_train_loss 213.01 acc_train_error 5.40% test_error 15.70%
# 211 acc_train_loss 212.29 acc_train_error 5.40% test_error 16.10%
# 212 acc_train_loss 211.68 acc_train_error 5.40% test_error 15.80%
# 213 acc_train_loss 211.51 acc_train_error 5.30% test_error 16.10%
# 214 acc_train_loss 211.47 acc_train_error 5.30% test_error 15.90%
# 215 acc_train_loss 212.04 acc_train_error 5.20% test_error 16.30%
# 216 acc_train_loss 212.78 acc_train_error 5.30% test_error 15.80%
# 217 acc_train_loss 214.46 acc_train_error 5.10% test_error 16.10%
# 218 acc_train_loss 216.33 acc_train_error 5.50% test_error 16.30%
# 219 acc_train_loss 219.50 acc_train_error 5.10% test_error 15.70%
# 220 acc_train_loss 222.68 acc_train_error 5.60% test_error 16.70%
# 221 acc_train_loss 227.28 acc_train_error 5.20% test_error 15.60%
# 222 acc_train_loss 230.98 acc_train_error 5.90% test_error 16.80%
# 223 acc_train_loss 235.62 acc_train_error 5.40% test_error 16.10%
# 224 acc_train_loss 237.32 acc_train_error 5.90% test_error 17.40%
# 225 acc_train_loss 239.38 acc_train_error 5.60% test_error 16.00%
# 226 acc_train_loss 236.70 acc_train_error 5.80% test_error 17.30%
# 227 acc_train_loss 235.28 acc_train_error 5.50% test_error 15.50%
# 228 acc_train_loss 229.47 acc_train_error 5.50% test_error 17.00%
# 229 acc_train_loss 226.64 acc_train_error 5.30% test_error 15.70%
# 230 acc_train_loss 220.90 acc_train_error 5.40% test_error 16.90%
# 231 acc_train_loss 218.59 acc_train_error 5.20% test_error 15.30%
# 232 acc_train_loss 214.39 acc_train_error 5.20% test_error 16.50%
# 233 acc_train_loss 212.99 acc_train_error 4.90% test_error 15.40%
# 234 acc_train_loss 210.23 acc_train_error 4.90% test_error 16.60%
# 235 acc_train_loss 209.48 acc_train_error 5.10% test_error 15.10%
# 236 acc_train_loss 207.70 acc_train_error 4.60% test_error 16.30%
# 237 acc_train_loss 207.26 acc_train_error 5.20% test_error 14.90%
# 238 acc_train_loss 206.07 acc_train_error 4.50% test_error 16.30%
# 239 acc_train_loss 205.68 acc_train_error 5.20% test_error 14.70%
# 240 acc_train_loss 204.77 acc_train_error 4.60% test_error 16.30%
# 241 acc_train_loss 204.21 acc_train_error 4.90% test_error 14.60%
# 242 acc_train_loss 203.35 acc_train_error 4.30% test_error 15.90%
# 243 acc_train_loss 202.52 acc_train_error 4.90% test_error 14.50%
# 244 acc_train_loss 201.58 acc_train_error 4.30% test_error 16.10%
# 245 acc_train_loss 200.46 acc_train_error 4.90% test_error 14.60%
# 246 acc_train_loss 199.41 acc_train_error 4.40% test_error 16.20%
# 247 acc_train_loss 198.08 acc_train_error 4.90% test_error 14.60%
# 248 acc_train_loss 196.96 acc_train_error 4.40% test_error 16.20%
# 249 acc_train_loss 195.55 acc_train_error 4.90% test_error 14.90%
# 250 acc_train_loss 194.45 acc_train_error 4.30% test_error 16.00%
# 251 acc_train_loss 193.07 acc_train_error 4.80% test_error 14.90%
# 252 acc_train_loss 192.08 acc_train_error 4.30% test_error 16.00%
# 253 acc_train_loss 190.81 acc_train_error 4.80% test_error 15.00%
# 254 acc_train_loss 189.99 acc_train_error 4.00% test_error 15.80%
# 255 acc_train_loss 188.88 acc_train_error 4.80% test_error 15.20%
# 256 acc_train_loss 188.27 acc_train_error 4.00% test_error 15.80%
# 257 acc_train_loss 187.35 acc_train_error 4.70% test_error 15.30%
# 258 acc_train_loss 186.97 acc_train_error 4.10% test_error 15.70%
# 259 acc_train_loss 186.26 acc_train_error 4.60% test_error 15.30%
# 260 acc_train_loss 186.15 acc_train_error 4.10% test_error 15.90%
# 261 acc_train_loss 185.65 acc_train_error 4.60% test_error 15.50%
# 262 acc_train_loss 185.84 acc_train_error 4.10% test_error 16.00%
# 263 acc_train_loss 185.57 acc_train_error 4.50% test_error 15.70%
# 264 acc_train_loss 186.11 acc_train_error 4.10% test_error 15.90%
# 265 acc_train_loss 186.08 acc_train_error 4.60% test_error 15.90%
# 266 acc_train_loss 186.99 acc_train_error 4.10% test_error 15.60%
# 267 acc_train_loss 187.17 acc_train_error 4.60% test_error 16.00%
# 268 acc_train_loss 188.44 acc_train_error 4.20% test_error 15.60%
# 269 acc_train_loss 188.75 acc_train_error 4.70% test_error 16.20%
# 270 acc_train_loss 190.25 acc_train_error 4.20% test_error 15.10%
# 271 acc_train_loss 190.48 acc_train_error 4.80% test_error 16.20%
# 272 acc_train_loss 191.94 acc_train_error 4.10% test_error 15.20%
# 273 acc_train_loss 191.76 acc_train_error 4.90% test_error 16.20%
# 274 acc_train_loss 192.76 acc_train_error 4.10% test_error 14.80%
# 275 acc_train_loss 191.81 acc_train_error 4.90% test_error 16.20%
# 276 acc_train_loss 192.01 acc_train_error 4.10% test_error 14.50%
# 277 acc_train_loss 190.16 acc_train_error 4.70% test_error 16.30%
# 278 acc_train_loss 189.51 acc_train_error 4.20% test_error 14.30%
# 279 acc_train_loss 186.99 acc_train_error 4.30% test_error 16.10%
# 280 acc_train_loss 185.77 acc_train_error 4.00% test_error 14.50%
# 281 acc_train_loss 183.01 acc_train_error 4.20% test_error 16.10%
# 282 acc_train_loss 181.63 acc_train_error 4.00% test_error 14.60%
# 283 acc_train_loss 179.01 acc_train_error 4.00% test_error 16.00%
# 284 acc_train_loss 177.75 acc_train_error 3.90% test_error 14.80%
# 285 acc_train_loss 175.47 acc_train_error 4.00% test_error 16.10%
# 286 acc_train_loss 174.45 acc_train_error 3.80% test_error 14.90%
# 287 acc_train_loss 172.55 acc_train_error 3.90% test_error 16.10%
# 288 acc_train_loss 171.80 acc_train_error 3.80% test_error 14.90%
# 289 acc_train_loss 170.25 acc_train_error 3.90% test_error 16.10%
# 290 acc_train_loss 169.75 acc_train_error 3.70% test_error 14.70%
# 291 acc_train_loss 168.49 acc_train_error 3.90% test_error 16.20%
# 292 acc_train_loss 168.19 acc_train_error 3.70% test_error 14.70%
# 293 acc_train_loss 167.16 acc_train_error 3.90% test_error 16.20%
# 294 acc_train_loss 167.03 acc_train_error 3.70% test_error 14.70%
# 295 acc_train_loss 166.19 acc_train_error 3.90% test_error 16.20%
# 296 acc_train_loss 166.20 acc_train_error 3.80% test_error 14.70%
# 297 acc_train_loss 165.49 acc_train_error 3.70% test_error 16.30%
# 298 acc_train_loss 165.59 acc_train_error 3.80% test_error 14.70%
# 299 acc_train_loss 164.96 acc_train_error 3.70% test_error 16.40%
# 300 acc_train_loss 165.12 acc_train_error 3.80% test_error 14.70%
# 301 acc_train_loss 164.52 acc_train_error 3.70% test_error 16.40%
# 302 acc_train_loss 164.69 acc_train_error 3.80% test_error 14.70%
# 303 acc_train_loss 164.07 acc_train_error 3.70% test_error 16.50%
# 304 acc_train_loss 164.19 acc_train_error 3.80% test_error 14.50%
# 305 acc_train_loss 163.49 acc_train_error 3.70% test_error 16.50%
# 306 acc_train_loss 163.53 acc_train_error 3.80% test_error 14.60%
# 307 acc_train_loss 162.72 acc_train_error 3.70% test_error 16.40%
# 308 acc_train_loss 162.65 acc_train_error 3.80% test_error 14.70%
# 309 acc_train_loss 161.72 acc_train_error 3.70% test_error 16.30%
# 310 acc_train_loss 161.53 acc_train_error 3.80% test_error 14.80%
# 311 acc_train_loss 160.50 acc_train_error 3.70% test_error 16.30%
# 312 acc_train_loss 160.21 acc_train_error 3.80% test_error 14.80%
# 313 acc_train_loss 159.12 acc_train_error 3.70% test_error 16.40%
# 314 acc_train_loss 158.77 acc_train_error 3.80% test_error 14.90%
# 315 acc_train_loss 157.65 acc_train_error 3.70% test_error 16.40%
# 316 acc_train_loss 157.28 acc_train_error 3.80% test_error 15.20%
# 317 acc_train_loss 156.18 acc_train_error 3.70% test_error 16.40%
# 318 acc_train_loss 155.84 acc_train_error 3.80% test_error 15.10%
# 319 acc_train_loss 154.82 acc_train_error 3.70% test_error 16.40%
# 320 acc_train_loss 154.56 acc_train_error 3.70% test_error 15.10%
# 321 acc_train_loss 153.65 acc_train_error 3.50% test_error 16.10%
# 322 acc_train_loss 153.55 acc_train_error 3.70% test_error 15.10%
# 323 acc_train_loss 152.83 acc_train_error 3.50% test_error 16.10%
# 324 acc_train_loss 153.01 acc_train_error 3.70% test_error 14.80%
# 325 acc_train_loss 152.60 acc_train_error 3.50% test_error 16.10%
# 326 acc_train_loss 153.29 acc_train_error 3.40% test_error 15.00%
# 327 acc_train_loss 153.45 acc_train_error 3.40% test_error 16.30%
# 328 acc_train_loss 155.08 acc_train_error 3.50% test_error 15.00%
# 329 acc_train_loss 156.24 acc_train_error 3.50% test_error 16.00%
# 330 acc_train_loss 159.48 acc_train_error 3.50% test_error 15.10%
# 331 acc_train_loss 162.15 acc_train_error 3.60% test_error 16.60%
# 332 acc_train_loss 167.51 acc_train_error 3.60% test_error 15.40%
# 333 acc_train_loss 171.38 acc_train_error 3.80% test_error 17.00%
# 334 acc_train_loss 177.74 acc_train_error 3.90% test_error 15.80%
# 335 acc_train_loss 180.14 acc_train_error 3.60% test_error 17.20%
# 336 acc_train_loss 183.68 acc_train_error 3.90% test_error 16.00%
# 337 acc_train_loss 181.23 acc_train_error 3.60% test_error 16.90%
# 338 acc_train_loss 179.34 acc_train_error 3.90% test_error 16.00%
# 339 acc_train_loss 173.10 acc_train_error 3.50% test_error 16.30%
# 340 acc_train_loss 168.25 acc_train_error 3.70% test_error 16.20%
# 341 acc_train_loss 162.03 acc_train_error 3.40% test_error 15.70%
# 342 acc_train_loss 157.54 acc_train_error 3.10% test_error 16.00%
# 343 acc_train_loss 153.05 acc_train_error 3.30% test_error 15.60%
# 344 acc_train_loss 149.94 acc_train_error 2.90% test_error 16.20%
# 345 acc_train_loss 147.02 acc_train_error 3.30% test_error 15.30%
# 346 acc_train_loss 145.07 acc_train_error 2.80% test_error 16.20%
# 347 acc_train_loss 143.18 acc_train_error 3.20% test_error 15.30%
# 348 acc_train_loss 142.00 acc_train_error 2.90% test_error 16.10%
# 349 acc_train_loss 140.78 acc_train_error 3.30% test_error 15.50%
# 350 acc_train_loss 140.11 acc_train_error 2.80% test_error 16.10%
# 351 acc_train_loss 139.35 acc_train_error 3.30% test_error 15.40%
# 352 acc_train_loss 139.10 acc_train_error 2.80% test_error 16.00%
# 353 acc_train_loss 138.73 acc_train_error 3.30% test_error 15.50%
# 354 acc_train_loss 138.89 acc_train_error 2.80% test_error 16.20%
# 355 acc_train_loss 138.96 acc_train_error 3.30% test_error 15.60%
# 356 acc_train_loss 139.62 acc_train_error 2.70% test_error 16.00%
# 357 acc_train_loss 140.29 acc_train_error 3.30% test_error 15.80%
# 358 acc_train_loss 141.66 acc_train_error 2.70% test_error 15.70%
# 359 acc_train_loss 143.23 acc_train_error 3.30% test_error 15.70%
# 360 acc_train_loss 145.70 acc_train_error 2.80% test_error 15.60%
# 361 acc_train_loss 148.58 acc_train_error 3.50% test_error 16.10%
# 362 acc_train_loss 152.52 acc_train_error 2.70% test_error 15.70%
# 363 acc_train_loss 156.88 acc_train_error 3.60% test_error 16.50%
# 364 acc_train_loss 162.12 acc_train_error 2.80% test_error 15.20%
# 365 acc_train_loss 166.72 acc_train_error 3.70% test_error 16.70%
# 366 acc_train_loss 171.38 acc_train_error 2.90% test_error 14.90%
# 367 acc_train_loss 172.74 acc_train_error 3.80% test_error 16.90%
# 368 acc_train_loss 173.98 acc_train_error 2.80% test_error 15.10%
# 369 acc_train_loss 169.97 acc_train_error 3.80% test_error 16.70%
# 370 acc_train_loss 168.05 acc_train_error 2.80% test_error 15.00%
# 371 acc_train_loss 161.75 acc_train_error 3.80% test_error 16.30%
# 372 acc_train_loss 159.52 acc_train_error 2.70% test_error 15.00%
# 373 acc_train_loss 154.62 acc_train_error 3.70% test_error 16.40%
# 374 acc_train_loss 153.45 acc_train_error 2.40% test_error 15.30%
# 375 acc_train_loss 150.57 acc_train_error 3.50% test_error 17.30%
# 376 acc_train_loss 150.10 acc_train_error 2.80% test_error 15.10%
# 377 acc_train_loss 148.31 acc_train_error 3.40% test_error 17.30%
# 378 acc_train_loss 147.82 acc_train_error 2.90% test_error 15.10%
# 379 acc_train_loss 146.29 acc_train_error 3.40% test_error 17.00%
# 380 acc_train_loss 145.41 acc_train_error 3.10% test_error 15.20%
# 381 acc_train_loss 143.87 acc_train_error 3.30% test_error 17.20%
# 382 acc_train_loss 142.72 acc_train_error 3.20% test_error 15.30%
# 383 acc_train_loss 141.34 acc_train_error 3.30% test_error 17.20%
# 384 acc_train_loss 140.27 acc_train_error 3.10% test_error 15.30%
# 385 acc_train_loss 139.34 acc_train_error 3.20% test_error 16.90%
# 386 acc_train_loss 138.72 acc_train_error 3.10% test_error 15.60%
# 387 acc_train_loss 138.48 acc_train_error 3.20% test_error 16.90%
# 388 acc_train_loss 138.53 acc_train_error 2.90% test_error 15.60%
# 389 acc_train_loss 139.12 acc_train_error 3.20% test_error 16.60%
# 390 acc_train_loss 139.91 acc_train_error 2.80% test_error 15.40%
# 391 acc_train_loss 141.28 acc_train_error 3.00% test_error 16.80%
# 392 acc_train_loss 142.55 acc_train_error 2.70% test_error 15.30%
# 393 acc_train_loss 144.31 acc_train_error 3.10% test_error 16.60%
# 394 acc_train_loss 145.38 acc_train_error 2.70% test_error 15.40%
# 395 acc_train_loss 146.75 acc_train_error 3.20% test_error 16.50%
# 396 acc_train_loss 146.79 acc_train_error 2.60% test_error 15.50%
# 397 acc_train_loss 147.11 acc_train_error 3.10% test_error 16.50%
# 398 acc_train_loss 145.92 acc_train_error 2.40% test_error 15.20%
# 399 acc_train_loss 145.24 acc_train_error 2.70% test_error 16.40%
# 400 acc_train_loss 143.49 acc_train_error 2.50% test_error 15.20%
# 401 acc_train_loss 142.51 acc_train_error 2.50% test_error 16.20%
# 402 acc_train_loss 141.24 acc_train_error 2.60% test_error 15.50%
# 403 acc_train_loss 140.80 acc_train_error 2.40% test_error 16.10%
# 404 acc_train_loss 140.91 acc_train_error 2.80% test_error 15.00%
# 405 acc_train_loss 141.76 acc_train_error 2.30% test_error 16.00%
# 406 acc_train_loss 144.06 acc_train_error 2.80% test_error 15.30%
# 407 acc_train_loss 146.70 acc_train_error 2.40% test_error 15.80%
# 408 acc_train_loss 151.62 acc_train_error 2.50% test_error 15.20%
# 409 acc_train_loss 155.40 acc_train_error 2.40% test_error 16.00%
# 410 acc_train_loss 161.43 acc_train_error 2.40% test_error 15.10%
# 411 acc_train_loss 162.74 acc_train_error 2.50% test_error 16.40%
# 412 acc_train_loss 165.22 acc_train_error 2.50% test_error 15.10%
# 413 acc_train_loss 159.96 acc_train_error 2.60% test_error 16.20%
# 414 acc_train_loss 156.34 acc_train_error 2.50% test_error 15.20%
# 415 acc_train_loss 147.20 acc_train_error 2.50% test_error 16.20%
# 416 acc_train_loss 141.42 acc_train_error 2.50% test_error 15.70%
# 417 acc_train_loss 133.94 acc_train_error 2.50% test_error 15.90%
# 418 acc_train_loss 129.59 acc_train_error 2.30% test_error 15.50%
# 419 acc_train_loss 125.07 acc_train_error 2.50% test_error 15.80%
# 420 acc_train_loss 122.51 acc_train_error 2.40% test_error 15.70%
# 421 acc_train_loss 119.95 acc_train_error 2.60% test_error 15.80%
# 422 acc_train_loss 118.54 acc_train_error 2.40% test_error 15.70%
# 423 acc_train_loss 117.05 acc_train_error 2.60% test_error 16.10%
# 424 acc_train_loss 116.29 acc_train_error 2.30% test_error 15.80%
# 425 acc_train_loss 115.37 acc_train_error 2.60% test_error 16.10%
# 426 acc_train_loss 115.01 acc_train_error 2.30% test_error 15.70%
# 427 acc_train_loss 114.45 acc_train_error 2.60% test_error 16.00%
# 428 acc_train_loss 114.37 acc_train_error 2.30% test_error 15.60%
# 429 acc_train_loss 114.08 acc_train_error 2.60% test_error 16.20%
# 430 acc_train_loss 114.28 acc_train_error 2.30% test_error 15.70%
# 431 acc_train_loss 114.27 acc_train_error 2.60% test_error 16.10%
# 432 acc_train_loss 114.81 acc_train_error 2.20% test_error 15.70%
# 433 acc_train_loss 115.15 acc_train_error 2.60% test_error 16.20%
# 434 acc_train_loss 116.13 acc_train_error 2.20% test_error 15.90%
# 435 acc_train_loss 116.96 acc_train_error 2.60% test_error 16.40%
# 436 acc_train_loss 118.56 acc_train_error 2.10% test_error 15.90%
# 437 acc_train_loss 120.03 acc_train_error 2.70% test_error 16.50%
# 438 acc_train_loss 122.38 acc_train_error 2.10% test_error 15.60%
# 439 acc_train_loss 124.59 acc_train_error 2.70% test_error 16.80%
# 440 acc_train_loss 127.63 acc_train_error 2.10% test_error 15.50%
# 441 acc_train_loss 130.35 acc_train_error 2.60% test_error 16.80%
# 442 acc_train_loss 133.53 acc_train_error 2.30% test_error 15.40%
# 443 acc_train_loss 135.98 acc_train_error 2.70% test_error 16.90%
# 444 acc_train_loss 138.19 acc_train_error 2.30% test_error 15.30%
# 445 acc_train_loss 139.29 acc_train_error 2.50% test_error 17.00%
# 446 acc_train_loss 139.64 acc_train_error 2.00% test_error 14.90%
# 447 acc_train_loss 138.91 acc_train_error 2.30% test_error 17.20%
# 448 acc_train_loss 137.56 acc_train_error 1.90% test_error 15.10%
# 449 acc_train_loss 135.63 acc_train_error 2.20% test_error 17.00%
# 450 acc_train_loss 133.60 acc_train_error 1.80% test_error 14.90%
# 451 acc_train_loss 131.50 acc_train_error 2.20% test_error 16.70%
# 452 acc_train_loss 129.76 acc_train_error 1.90% test_error 15.00%
# 453 acc_train_loss 128.15 acc_train_error 2.10% test_error 16.50%
# 454 acc_train_loss 127.15 acc_train_error 1.90% test_error 15.10%
# 455 acc_train_loss 126.27 acc_train_error 1.90% test_error 16.40%
# 456 acc_train_loss 126.14 acc_train_error 1.70% test_error 15.10%
# 457 acc_train_loss 125.94 acc_train_error 1.90% test_error 16.30%
# 458 acc_train_loss 126.67 acc_train_error 1.80% test_error 15.00%
# 459 acc_train_loss 126.99 acc_train_error 1.80% test_error 16.20%
# 460 acc_train_loss 128.49 acc_train_error 1.70% test_error 15.10%
# 461 acc_train_loss 128.98 acc_train_error 1.80% test_error 16.20%
# 462 acc_train_loss 130.98 acc_train_error 1.70% test_error 15.30%
# 463 acc_train_loss 131.07 acc_train_error 1.90% test_error 16.20%
# 464 acc_train_loss 133.03 acc_train_error 1.80% test_error 15.10%
# 465 acc_train_loss 132.06 acc_train_error 1.70% test_error 16.10%
# 466 acc_train_loss 133.26 acc_train_error 1.90% test_error 15.20%
# 467 acc_train_loss 130.91 acc_train_error 1.80% test_error 16.30%
# 468 acc_train_loss 130.96 acc_train_error 1.80% test_error 15.20%
# 469 acc_train_loss 127.64 acc_train_error 1.80% test_error 16.20%
# 470 acc_train_loss 126.76 acc_train_error 1.90% test_error 15.10%
# 471 acc_train_loss 123.34 acc_train_error 1.90% test_error 16.20%
# 472 acc_train_loss 122.16 acc_train_error 1.60% test_error 15.20%
# 473 acc_train_loss 119.37 acc_train_error 2.10% test_error 16.20%
# 474 acc_train_loss 118.47 acc_train_error 1.60% test_error 15.30%
# 475 acc_train_loss 116.63 acc_train_error 1.90% test_error 16.00%
# 476 acc_train_loss 116.31 acc_train_error 1.60% test_error 15.50%
# 477 acc_train_loss 115.51 acc_train_error 1.70% test_error 16.00%
# 478 acc_train_loss 115.93 acc_train_error 1.60% test_error 15.60%
# 479 acc_train_loss 116.18 acc_train_error 1.80% test_error 15.90%
# 480 acc_train_loss 117.43 acc_train_error 1.40% test_error 15.90%
# 481 acc_train_loss 118.76 acc_train_error 1.80% test_error 16.20%
# 482 acc_train_loss 120.82 acc_train_error 1.30% test_error 15.50%
# 483 acc_train_loss 123.08 acc_train_error 2.10% test_error 16.10%
# 484 acc_train_loss 125.55 acc_train_error 1.30% test_error 15.60%
# 485 acc_train_loss 128.10 acc_train_error 2.10% test_error 15.90%
# 486 acc_train_loss 129.92 acc_train_error 1.50% test_error 15.60%
# 487 acc_train_loss 131.51 acc_train_error 2.10% test_error 16.00%
# 488 acc_train_loss 131.36 acc_train_error 1.60% test_error 15.80%
# 489 acc_train_loss 130.99 acc_train_error 2.00% test_error 15.70%
# 490 acc_train_loss 128.57 acc_train_error 1.60% test_error 15.70%
# 491 acc_train_loss 126.55 acc_train_error 2.00% test_error 15.60%
# 492 acc_train_loss 123.00 acc_train_error 1.60% test_error 15.60%
# 493 acc_train_loss 120.55 acc_train_error 1.90% test_error 15.50%
# 494 acc_train_loss 117.20 acc_train_error 1.60% test_error 15.60%
# 495 acc_train_loss 115.23 acc_train_error 1.90% test_error 15.60%
# 496 acc_train_loss 112.74 acc_train_error 1.50% test_error 15.70%
# 497 acc_train_loss 111.58 acc_train_error 1.70% test_error 15.60%
# 498 acc_train_loss 110.07 acc_train_error 1.40% test_error 15.90%
# 499 acc_train_loss 109.81 acc_train_error 1.60% test_error 15.10%
# 500 acc_train_loss 109.35 acc_train_error 1.40% test_error 16.10%
# 501 acc_train_loss 110.16 acc_train_error 1.70% test_error 14.90%
# 502 acc_train_loss 111.01 acc_train_error 1.50% test_error 16.40%
# 503 acc_train_loss 113.35 acc_train_error 1.60% test_error 15.20%
# 504 acc_train_loss 116.10 acc_train_error 1.50% test_error 16.80%
# 505 acc_train_loss 120.62 acc_train_error 1.70% test_error 14.90%
# 506 acc_train_loss 125.74 acc_train_error 1.80% test_error 17.40%
# 507 acc_train_loss 132.31 acc_train_error 1.70% test_error 15.10%
# 508 acc_train_loss 138.30 acc_train_error 1.90% test_error 17.50%
# 509 acc_train_loss 143.46 acc_train_error 1.80% test_error 15.10%
# 510 acc_train_loss 145.29 acc_train_error 1.90% test_error 17.10%
# 511 acc_train_loss 143.80 acc_train_error 1.60% test_error 15.20%
# 512 acc_train_loss 139.05 acc_train_error 1.70% test_error 16.90%
# 513 acc_train_loss 132.33 acc_train_error 1.50% test_error 15.20%
# 514 acc_train_loss 125.54 acc_train_error 1.60% test_error 16.40%
# 515 acc_train_loss 119.08 acc_train_error 1.50% test_error 15.40%
# 516 acc_train_loss 114.02 acc_train_error 1.40% test_error 16.30%
# 517 acc_train_loss 109.88 acc_train_error 1.50% test_error 15.40%
# 518 acc_train_loss 106.89 acc_train_error 1.40% test_error 16.10%
# 519 acc_train_loss 104.65 acc_train_error 1.50% test_error 15.50%
# 520 acc_train_loss 103.07 acc_train_error 1.40% test_error 15.80%
# 521 acc_train_loss 102.01 acc_train_error 1.40% test_error 15.50%
# 522 acc_train_loss 101.31 acc_train_error 1.40% test_error 15.80%
# 523 acc_train_loss 101.02 acc_train_error 1.40% test_error 15.80%
# 524 acc_train_loss 100.97 acc_train_error 1.30% test_error 15.80%
# 525 acc_train_loss 101.27 acc_train_error 1.40% test_error 15.90%
# 526 acc_train_loss 101.78 acc_train_error 1.40% test_error 15.70%
# 527 acc_train_loss 102.61 acc_train_error 1.40% test_error 16.00%
# 528 acc_train_loss 103.68 acc_train_error 1.20% test_error 15.50%
# 529 acc_train_loss 105.01 acc_train_error 1.40% test_error 16.10%
# 530 acc_train_loss 106.60 acc_train_error 1.20% test_error 15.70%
# 531 acc_train_loss 108.26 acc_train_error 1.40% test_error 16.00%
# 532 acc_train_loss 110.14 acc_train_error 1.20% test_error 15.60%
# 533 acc_train_loss 111.75 acc_train_error 1.40% test_error 16.20%
# 534 acc_train_loss 113.42 acc_train_error 1.20% test_error 15.60%
# 535 acc_train_loss 114.41 acc_train_error 1.50% test_error 16.20%
# 536 acc_train_loss 115.25 acc_train_error 1.40% test_error 15.60%
# 537 acc_train_loss 115.20 acc_train_error 1.50% test_error 16.20%
# 538 acc_train_loss 114.91 acc_train_error 1.40% test_error 15.70%
# 539 acc_train_loss 113.91 acc_train_error 1.50% test_error 16.10%
# 540 acc_train_loss 112.73 acc_train_error 1.30% test_error 15.40%
# 541 acc_train_loss 111.33 acc_train_error 1.60% test_error 16.10%
# 542 acc_train_loss 109.83 acc_train_error 1.20% test_error 15.40%
# 543 acc_train_loss 108.65 acc_train_error 1.60% test_error 16.10%
# 544 acc_train_loss 107.36 acc_train_error 1.10% test_error 15.50%
# 545 acc_train_loss 106.85 acc_train_error 1.60% test_error 15.70%
# 546 acc_train_loss 106.14 acc_train_error 1.20% test_error 15.50%
# 547 acc_train_loss 106.58 acc_train_error 1.50% test_error 15.50%
# 548 acc_train_loss 106.66 acc_train_error 1.00% test_error 16.00%
# 549 acc_train_loss 108.25 acc_train_error 1.40% test_error 15.60%
# 550 acc_train_loss 109.14 acc_train_error 1.00% test_error 16.00%
# 551 acc_train_loss 111.86 acc_train_error 1.30% test_error 15.80%
# 552 acc_train_loss 113.18 acc_train_error 1.10% test_error 16.10%
# 553 acc_train_loss 116.43 acc_train_error 1.40% test_error 15.80%
# 554 acc_train_loss 117.13 acc_train_error 1.10% test_error 16.10%
# 555 acc_train_loss 119.64 acc_train_error 1.40% test_error 15.60%
# 556 acc_train_loss 118.60 acc_train_error 1.20% test_error 16.20%
# 557 acc_train_loss 119.30 acc_train_error 1.40% test_error 15.60%
# 558 acc_train_loss 116.63 acc_train_error 1.20% test_error 16.40%
# 559 acc_train_loss 115.93 acc_train_error 1.30% test_error 15.40%
# 560 acc_train_loss 113.06 acc_train_error 1.30% test_error 16.40%
# 561 acc_train_loss 112.29 acc_train_error 1.20% test_error 15.20%
# 562 acc_train_loss 110.63 acc_train_error 1.10% test_error 16.40%
# 563 acc_train_loss 110.97 acc_train_error 1.20% test_error 15.10%
# 564 acc_train_loss 111.28 acc_train_error 1.20% test_error 16.40%
# 565 acc_train_loss 113.35 acc_train_error 1.40% test_error 15.10%
# 566 acc_train_loss 115.74 acc_train_error 1.30% test_error 16.50%
# 567 acc_train_loss 119.40 acc_train_error 1.40% test_error 15.30%
# 568 acc_train_loss 123.00 acc_train_error 1.40% test_error 16.90%
# 569 acc_train_loss 126.61 acc_train_error 1.50% test_error 15.70%
# 570 acc_train_loss 128.92 acc_train_error 1.40% test_error 16.90%
# 571 acc_train_loss 129.51 acc_train_error 1.40% test_error 15.70%
# 572 acc_train_loss 128.11 acc_train_error 1.30% test_error 16.50%
# 573 acc_train_loss 124.62 acc_train_error 1.30% test_error 15.60%
# 574 acc_train_loss 120.21 acc_train_error 1.30% test_error 16.10%
# 575 acc_train_loss 115.02 acc_train_error 1.20% test_error 15.40%
# 576 acc_train_loss 110.28 acc_train_error 1.20% test_error 15.90%
# 577 acc_train_loss 105.88 acc_train_error 1.00% test_error 15.60%
# 578 acc_train_loss 102.32 acc_train_error 1.10% test_error 15.60%
# 579 acc_train_loss 99.43 acc_train_error 1.00% test_error 15.70%
# 580 acc_train_loss 97.15 acc_train_error 0.90% test_error 15.60%
# 581 acc_train_loss 95.53 acc_train_error 1.00% test_error 15.80%
# 582 acc_train_loss 94.26 acc_train_error 0.90% test_error 15.50%
# 583 acc_train_loss 93.56 acc_train_error 1.00% test_error 16.00%
# 584 acc_train_loss 93.10 acc_train_error 0.80% test_error 15.20%
# 585 acc_train_loss 93.21 acc_train_error 1.00% test_error 16.20%
# 586 acc_train_loss 93.59 acc_train_error 0.90% test_error 15.00%
# 587 acc_train_loss 94.64 acc_train_error 1.10% test_error 16.30%
# 588 acc_train_loss 96.17 acc_train_error 0.90% test_error 14.90%
# 589 acc_train_loss 98.54 acc_train_error 1.00% test_error 16.30%
# 590 acc_train_loss 101.77 acc_train_error 0.90% test_error 15.00%
# 591 acc_train_loss 105.83 acc_train_error 1.20% test_error 16.60%
# 592 acc_train_loss 110.89 acc_train_error 0.80% test_error 15.00%
# 593 acc_train_loss 115.91 acc_train_error 1.30% test_error 17.00%
# 594 acc_train_loss 120.99 acc_train_error 0.90% test_error 15.00%
# 595 acc_train_loss 123.97 acc_train_error 1.30% test_error 17.10%
# 596 acc_train_loss 125.34 acc_train_error 0.90% test_error 15.00%
# 597 acc_train_loss 123.59 acc_train_error 1.30% test_error 16.70%
# 598 acc_train_loss 120.32 acc_train_error 0.80% test_error 15.10%
# 599 acc_train_loss 115.60 acc_train_error 1.20% test_error 16.50%
# 600 acc_train_loss 110.94 acc_train_error 0.70% test_error 14.90%
# 601 acc_train_loss 106.51 acc_train_error 1.20% test_error 16.50%
# 602 acc_train_loss 103.09 acc_train_error 0.70% test_error 15.10%
# 603 acc_train_loss 100.19 acc_train_error 1.20% test_error 16.30%
# 604 acc_train_loss 98.43 acc_train_error 0.60% test_error 15.30%
# 605 acc_train_loss 96.93 acc_train_error 1.20% test_error 16.30%
# 606 acc_train_loss 96.46 acc_train_error 0.80% test_error 15.40%
# 607 acc_train_loss 95.96 acc_train_error 1.20% test_error 16.10%
# 608 acc_train_loss 96.44 acc_train_error 0.80% test_error 15.30%
# 609 acc_train_loss 96.70 acc_train_error 1.10% test_error 16.10%
# 610 acc_train_loss 97.89 acc_train_error 0.80% test_error 15.20%
# 611 acc_train_loss 98.78 acc_train_error 1.10% test_error 16.20%
# 612 acc_train_loss 100.51 acc_train_error 0.80% test_error 15.30%
# 613 acc_train_loss 101.89 acc_train_error 1.00% test_error 16.20%
# 614 acc_train_loss 103.94 acc_train_error 0.80% test_error 15.30%
# 615 acc_train_loss 105.54 acc_train_error 0.90% test_error 16.30%
# 616 acc_train_loss 107.54 acc_train_error 0.80% test_error 15.10%
# 617 acc_train_loss 108.92 acc_train_error 1.00% test_error 16.30%
# 618 acc_train_loss 110.39 acc_train_error 0.90% test_error 15.20%
# 619 acc_train_loss 111.06 acc_train_error 1.00% test_error 16.30%
# 620 acc_train_loss 111.61 acc_train_error 0.90% test_error 15.20%
# 621 acc_train_loss 111.30 acc_train_error 1.10% test_error 16.10%
# 622 acc_train_loss 110.89 acc_train_error 0.80% test_error 15.10%
# 623 acc_train_loss 109.73 acc_train_error 1.10% test_error 16.10%
# 624 acc_train_loss 108.65 acc_train_error 0.90% test_error 15.10%
# 625 acc_train_loss 107.03 acc_train_error 1.00% test_error 16.00%
# 626 acc_train_loss 105.70 acc_train_error 0.90% test_error 15.30%
# 627 acc_train_loss 104.04 acc_train_error 1.00% test_error 15.90%
# 628 acc_train_loss 102.75 acc_train_error 0.90% test_error 15.30%
# 629 acc_train_loss 101.29 acc_train_error 1.00% test_error 15.80%
# 630 acc_train_loss 100.17 acc_train_error 0.80% test_error 15.40%
# 631 acc_train_loss 99.00 acc_train_error 1.00% test_error 15.80%
# 632 acc_train_loss 98.08 acc_train_error 0.90% test_error 15.40%
# 633 acc_train_loss 97.16 acc_train_error 0.90% test_error 15.70%
# 634 acc_train_loss 96.41 acc_train_error 0.90% test_error 15.40%
# 635 acc_train_loss 95.70 acc_train_error 0.90% test_error 15.70%
# 636 acc_train_loss 95.08 acc_train_error 0.90% test_error 15.50%
# 637 acc_train_loss 94.51 acc_train_error 0.80% test_error 15.90%
# 638 acc_train_loss 93.99 acc_train_error 0.90% test_error 15.50%
# 639 acc_train_loss 93.52 acc_train_error 0.80% test_error 15.80%
# 640 acc_train_loss 93.10 acc_train_error 0.90% test_error 15.60%
# 641 acc_train_loss 92.70 acc_train_error 0.80% test_error 15.80%
# 642 acc_train_loss 92.36 acc_train_error 0.90% test_error 15.60%
# 643 acc_train_loss 92.03 acc_train_error 0.80% test_error 15.60%
# 644 acc_train_loss 91.81 acc_train_error 0.90% test_error 15.70%
# 645 acc_train_loss 91.54 acc_train_error 0.60% test_error 15.60%
# 646 acc_train_loss 91.48 acc_train_error 0.90% test_error 15.60%
# 647 acc_train_loss 91.31 acc_train_error 0.70% test_error 15.90%
# 648 acc_train_loss 91.46 acc_train_error 0.90% test_error 15.80%
# 649 acc_train_loss 91.45 acc_train_error 0.70% test_error 15.90%
# 650 acc_train_loss 91.92 acc_train_error 0.90% test_error 15.90%
# 651 acc_train_loss 92.15 acc_train_error 0.70% test_error 15.90%
# 652 acc_train_loss 93.10 acc_train_error 0.90% test_error 16.20%
# 653 acc_train_loss 93.73 acc_train_error 0.60% test_error 16.00%
# 654 acc_train_loss 95.36 acc_train_error 0.80% test_error 16.00%
# 655 acc_train_loss 96.57 acc_train_error 0.60% test_error 15.90%
# 656 acc_train_loss 99.02 acc_train_error 0.80% test_error 15.90%
# 657 acc_train_loss 100.84 acc_train_error 0.60% test_error 16.00%
# 658 acc_train_loss 103.83 acc_train_error 0.90% test_error 16.10%
# 659 acc_train_loss 105.64 acc_train_error 0.60% test_error 15.90%
# 660 acc_train_loss 108.00 acc_train_error 0.90% test_error 16.10%
# 661 acc_train_loss 108.38 acc_train_error 0.60% test_error 15.70%
# 662 acc_train_loss 108.62 acc_train_error 0.90% test_error 16.10%
# 663 acc_train_loss 106.62 acc_train_error 0.60% test_error 15.50%
# 664 acc_train_loss 104.70 acc_train_error 0.90% test_error 16.20%
# 665 acc_train_loss 101.29 acc_train_error 0.60% test_error 15.80%
# 666 acc_train_loss 98.69 acc_train_error 0.80% test_error 15.80%
# 667 acc_train_loss 95.52 acc_train_error 0.60% test_error 15.70%
# 668 acc_train_loss 93.48 acc_train_error 0.90% test_error 15.50%
# 669 acc_train_loss 91.35 acc_train_error 0.60% test_error 15.50%
# 670 acc_train_loss 90.24 acc_train_error 0.90% test_error 15.40%
# 671 acc_train_loss 89.22 acc_train_error 0.70% test_error 15.70%
# 672 acc_train_loss 88.96 acc_train_error 0.70% test_error 15.40%
# 673 acc_train_loss 88.88 acc_train_error 0.70% test_error 15.50%
# 674 acc_train_loss 89.29 acc_train_error 0.70% test_error 15.30%
# 675 acc_train_loss 89.96 acc_train_error 0.80% test_error 15.60%
# 676 acc_train_loss 90.85 acc_train_error 0.70% test_error 15.30%
# 677 acc_train_loss 92.05 acc_train_error 0.80% test_error 15.50%
# 678 acc_train_loss 93.13 acc_train_error 0.70% test_error 15.30%
# 679 acc_train_loss 94.57 acc_train_error 0.90% test_error 15.60%
# 680 acc_train_loss 95.50 acc_train_error 0.80% test_error 15.40%
# 681 acc_train_loss 96.79 acc_train_error 0.90% test_error 15.90%
# 682 acc_train_loss 97.23 acc_train_error 0.80% test_error 15.20%
# 683 acc_train_loss 98.09 acc_train_error 0.80% test_error 16.00%
# 684 acc_train_loss 97.90 acc_train_error 0.80% test_error 15.20%
# 685 acc_train_loss 98.25 acc_train_error 0.80% test_error 15.90%
# 686 acc_train_loss 97.63 acc_train_error 0.80% test_error 15.30%
# 687 acc_train_loss 97.66 acc_train_error 0.70% test_error 16.10%
# 688 acc_train_loss 97.01 acc_train_error 0.70% test_error 15.40%
# 689 acc_train_loss 97.06 acc_train_error 0.70% test_error 16.10%
# 690 acc_train_loss 96.72 acc_train_error 0.60% test_error 15.50%
# 691 acc_train_loss 97.06 acc_train_error 0.70% test_error 16.00%
# 692 acc_train_loss 97.23 acc_train_error 0.60% test_error 15.50%
# 693 acc_train_loss 97.95 acc_train_error 0.60% test_error 15.90%
# 694 acc_train_loss 98.59 acc_train_error 0.60% test_error 15.40%
# 695 acc_train_loss 99.56 acc_train_error 0.60% test_error 15.70%
# 696 acc_train_loss 100.42 acc_train_error 0.70% test_error 16.00%
# 697 acc_train_loss 101.32 acc_train_error 0.70% test_error 15.60%
# 698 acc_train_loss 102.03 acc_train_error 0.80% test_error 16.10%
# 699 acc_train_loss 102.49 acc_train_error 0.70% test_error 15.50%
# 700 acc_train_loss 102.75 acc_train_error 0.70% test_error 16.10%
# 701 acc_train_loss 102.59 acc_train_error 0.60% test_error 15.40%
# 702 acc_train_loss 102.33 acc_train_error 0.70% test_error 16.30%
# 703 acc_train_loss 101.67 acc_train_error 0.60% test_error 15.30%
# 704 acc_train_loss 101.03 acc_train_error 0.70% test_error 16.60%
# 705 acc_train_loss 100.19 acc_train_error 0.50% test_error 15.20%
# 706 acc_train_loss 99.41 acc_train_error 0.80% test_error 16.70%
# 707 acc_train_loss 98.70 acc_train_error 0.50% test_error 15.00%
# 708 acc_train_loss 97.88 acc_train_error 0.80% test_error 16.70%
# 709 acc_train_loss 97.40 acc_train_error 0.50% test_error 14.90%
# 710 acc_train_loss 96.49 acc_train_error 0.80% test_error 16.70%
# 711 acc_train_loss 96.15 acc_train_error 0.50% test_error 14.80%
# 712 acc_train_loss 95.03 acc_train_error 0.80% test_error 16.50%
# 713 acc_train_loss 94.67 acc_train_error 0.50% test_error 14.80%
# 714 acc_train_loss 93.27 acc_train_error 0.70% test_error 16.50%
# ...
# 754 acc_train_loss 94.74 acc_train_error 0.50% test_error 15.70%
# 755 acc_train_loss 96.98 acc_train_error 0.50% test_error 16.20%
# 756 acc_train_loss 97.77 acc_train_error 0.50% test_error 15.60%
# 757 acc_train_loss 98.80 acc_train_error 0.50% test_error 16.40%
# 758 acc_train_loss 98.06 acc_train_error 0.60% test_error 15.60%
# 759 acc_train_loss 97.56 acc_train_error 0.50% test_error 16.40%
# 760 acc_train_loss 95.63 acc_train_error 0.60% test_error 15.60%
# 761 acc_train_loss 94.15 acc_train_error 0.50% test_error 16.00%
# 762 acc_train_loss 91.94 acc_train_error 0.60% test_error 15.40%
# 763 acc_train_loss 90.33 acc_train_error 0.50% test_error 15.90%
# 764 acc_train_loss 88.59 acc_train_error 0.60% test_error 15.40%
# 765 acc_train_loss 87.48 acc_train_error 0.50% test_error 15.90%
# 766 acc_train_loss 86.56 acc_train_error 0.60% test_error 15.50%
# 767 acc_train_loss 86.25 acc_train_error 0.40% test_error 15.80%
# 768 acc_train_loss 86.21 acc_train_error 0.50% test_error 15.80%
# 769 acc_train_loss 86.78 acc_train_error 0.40% test_error 15.90%
# 770 acc_train_loss 87.57 acc_train_error 0.50% test_error 15.60%
# 771 acc_train_loss 88.95 acc_train_error 0.40% test_error 15.90%
# 772 acc_train_loss 90.37 acc_train_error 0.40% test_error 15.90%
# 773 acc_train_loss 92.27 acc_train_error 0.40% test_error 15.80%
# 774 acc_train_loss 93.89 acc_train_error 0.40% test_error 15.70%
# 775 acc_train_loss 95.70 acc_train_error 0.40% test_error 15.90%
# 776 acc_train_loss 96.84 acc_train_error 0.40% test_error 15.90%
# 777 acc_train_loss 97.80 acc_train_error 0.40% test_error 15.90%
# 778 acc_train_loss 97.79 acc_train_error 0.40% test_error 15.90%
# 779 acc_train_loss 97.36 acc_train_error 0.40% test_error 15.90%
# 780 acc_train_loss 95.97 acc_train_error 0.40% test_error 15.70%
# 781 acc_train_loss 94.28 acc_train_error 0.40% test_error 15.70%
# 782 acc_train_loss 91.90 acc_train_error 0.40% test_error 15.70%
# 783 acc_train_loss 89.57 acc_train_error 0.40% test_error 15.70%
# 784 acc_train_loss 86.88 acc_train_error 0.40% test_error 15.70%
# 785 acc_train_loss 84.58 acc_train_error 0.40% test_error 15.50%
# 786 acc_train_loss 82.09 acc_train_error 0.40% test_error 15.70%
# 787 acc_train_loss 80.19 acc_train_error 0.40% test_error 15.50%
# 788 acc_train_loss 78.14 acc_train_error 0.30% test_error 15.80%
# 789 acc_train_loss 76.74 acc_train_error 0.40% test_error 15.40%
# 790 acc_train_loss 75.17 acc_train_error 0.30% test_error 15.90%
# 791 acc_train_loss 74.21 acc_train_error 0.40% test_error 15.30%
# 792 acc_train_loss 73.06 acc_train_error 0.30% test_error 15.80%
# 793 acc_train_loss 72.48 acc_train_error 0.40% test_error 15.20%
# 794 acc_train_loss 71.70 acc_train_error 0.30% test_error 16.00%
# 795 acc_train_loss 71.45 acc_train_error 0.40% test_error 15.40%
# 796 acc_train_loss 71.00 acc_train_error 0.30% test_error 16.00%
# 797 acc_train_loss 71.07 acc_train_error 0.40% test_error 15.30%
# 798 acc_train_loss 70.99 acc_train_error 0.40% test_error 16.20%
# 799 acc_train_loss 71.46 acc_train_error 0.40% test_error 15.20%
# 800 acc_train_loss 71.88 acc_train_error 0.40% test_error 16.20%
# 801 acc_train_loss 72.95 acc_train_error 0.40% test_error 15.40%
# 802 acc_train_loss 74.13 acc_train_error 0.40% test_error 16.40%
# 803 acc_train_loss 76.15 acc_train_error 0.40% test_error 15.30%
# 804 acc_train_loss 78.50 acc_train_error 0.50% test_error 16.50%
# 805 acc_train_loss 81.99 acc_train_error 0.40% test_error 15.20%
# 806 acc_train_loss 85.87 acc_train_error 0.50% test_error 16.90%
# 807 acc_train_loss 91.05 acc_train_error 0.50% test_error 15.00%
# 808 acc_train_loss 95.91 acc_train_error 0.80% test_error 16.70%
# 809 acc_train_loss 101.52 acc_train_error 0.50% test_error 14.90%
# 810 acc_train_loss 104.75 acc_train_error 0.80% test_error 16.50%
# 811 acc_train_loss 107.46 acc_train_error 0.50% test_error 14.80%
# 812 acc_train_loss 106.17 acc_train_error 0.80% test_error 16.40%
# 813 acc_train_loss 104.05 acc_train_error 0.50% test_error 14.90%
# 814 acc_train_loss 99.16 acc_train_error 0.80% test_error 16.40%
# 815 acc_train_loss 94.42 acc_train_error 0.50% test_error 15.10%
# 816 acc_train_loss 89.12 acc_train_error 0.70% test_error 16.60%
# 817 acc_train_loss 84.64 acc_train_error 0.50% test_error 15.30%
# 818 acc_train_loss 80.64 acc_train_error 0.70% test_error 16.20%
# 819 acc_train_loss 77.47 acc_train_error 0.50% test_error 15.10%
# 820 acc_train_loss 74.88 acc_train_error 0.60% test_error 16.30%
# 821 acc_train_loss 72.90 acc_train_error 0.40% test_error 15.10%
# 822 acc_train_loss 71.32 acc_train_error 0.50% test_error 16.20%
# 823 acc_train_loss 70.18 acc_train_error 0.40% test_error 15.00%
# 824 acc_train_loss 69.26 acc_train_error 0.50% test_error 16.00%
# 825 acc_train_loss 68.68 acc_train_error 0.40% test_error 14.90%
# 826 acc_train_loss 68.21 acc_train_error 0.50% test_error 15.80%
# 827 acc_train_loss 68.04 acc_train_error 0.40% test_error 14.80%
# 828 acc_train_loss 67.90 acc_train_error 0.50% test_error 15.70%
# 829 acc_train_loss 68.08 acc_train_error 0.40% test_error 14.90%
# 830 acc_train_loss 68.26 acc_train_error 0.40% test_error 15.80%
# 831 acc_train_loss 68.79 acc_train_error 0.40% test_error 15.20%
# 832 acc_train_loss 69.34 acc_train_error 0.40% test_error 15.70%
# 833 acc_train_loss 70.29 acc_train_error 0.50% test_error 15.40%
# 834 acc_train_loss 71.29 acc_train_error 0.40% test_error 15.50%
# 835 acc_train_loss 72.74 acc_train_error 0.50% test_error 15.70%
# 836 acc_train_loss 74.28 acc_train_error 0.40% test_error 15.40%
# 837 acc_train_loss 76.29 acc_train_error 0.40% test_error 15.70%
# 838 acc_train_loss 78.39 acc_train_error 0.40% test_error 15.50%
# 839 acc_train_loss 80.86 acc_train_error 0.40% test_error 15.60%
# 840 acc_train_loss 83.28 acc_train_error 0.40% test_error 15.60%
# 841 acc_train_loss 85.81 acc_train_error 0.40% test_error 15.70%
# 842 acc_train_loss 87.98 acc_train_error 0.40% test_error 15.40%
# 843 acc_train_loss 89.85 acc_train_error 0.40% test_error 15.90%
# 844 acc_train_loss 91.00 acc_train_error 0.50% test_error 15.40%
# 845 acc_train_loss 91.56 acc_train_error 0.40% test_error 16.10%
# 846 acc_train_loss 91.26 acc_train_error 0.50% test_error 15.50%
# 847 acc_train_loss 90.42 acc_train_error 0.40% test_error 16.00%
# 848 acc_train_loss 88.93 acc_train_error 0.50% test_error 15.50%
# 849 acc_train_loss 87.23 acc_train_error 0.40% test_error 16.00%
# 850 acc_train_loss 85.25 acc_train_error 0.50% test_error 15.60%
# 851 acc_train_loss 83.40 acc_train_error 0.40% test_error 16.20%
# 852 acc_train_loss 81.57 acc_train_error 0.30% test_error 15.20%
# 853 acc_train_loss 80.03 acc_train_error 0.30% test_error 16.20%
# 854 acc_train_loss 78.68 acc_train_error 0.40% test_error 15.30%
# 855 acc_train_loss 77.65 acc_train_error 0.30% test_error 16.10%
# 856 acc_train_loss 76.86 acc_train_error 0.40% test_error 15.40%
# 857 acc_train_loss 76.38 acc_train_error 0.20% test_error 16.10%
# 858 acc_train_loss 76.13 acc_train_error 0.40% test_error 15.60%
# 859 acc_train_loss 76.18 acc_train_error 0.40% test_error 16.00%
# 860 acc_train_loss 76.41 acc_train_error 0.30% test_error 15.80%
# 861 acc_train_loss 76.99 acc_train_error 0.40% test_error 15.90%
# 862 acc_train_loss 77.64 acc_train_error 0.30% test_error 15.90%
# 863 acc_train_loss 78.73 acc_train_error 0.40% test_error 15.90%
# 864 acc_train_loss 79.66 acc_train_error 0.30% test_error 16.20%
# 865 acc_train_loss 81.17 acc_train_error 0.40% test_error 15.80%
# 866 acc_train_loss 82.15 acc_train_error 0.30% test_error 16.10%
# 867 acc_train_loss 83.84 acc_train_error 0.40% test_error 15.90%
# 868 acc_train_loss 84.44 acc_train_error 0.40% test_error 16.00%
# 869 acc_train_loss 85.88 acc_train_error 0.40% test_error 15.80%
# 870 acc_train_loss 85.63 acc_train_error 0.40% test_error 16.20%
# 871 acc_train_loss 86.36 acc_train_error 0.40% test_error 15.70%
# 872 acc_train_loss 85.05 acc_train_error 0.40% test_error 16.10%
# 873 acc_train_loss 84.91 acc_train_error 0.40% test_error 15.90%
# 874 acc_train_loss 82.78 acc_train_error 0.30% test_error 16.00%
# 875 acc_train_loss 82.00 acc_train_error 0.40% test_error 16.10%
# 876 acc_train_loss 79.56 acc_train_error 0.30% test_error 16.00%
# 877 acc_train_loss 78.54 acc_train_error 0.40% test_error 15.90%
# 878 acc_train_loss 76.25 acc_train_error 0.30% test_error 16.10%
# 879 acc_train_loss 75.33 acc_train_error 0.40% test_error 16.00%
# 880 acc_train_loss 73.44 acc_train_error 0.30% test_error 16.00%
# 881 acc_train_loss 72.79 acc_train_error 0.40% test_error 15.80%
# 882 acc_train_loss 71.36 acc_train_error 0.30% test_error 15.90%
# 883 acc_train_loss 71.04 acc_train_error 0.40% test_error 15.90%
# 884 acc_train_loss 70.06 acc_train_error 0.30% test_error 15.90%
# 885 acc_train_loss 70.09 acc_train_error 0.40% test_error 15.90%
# 886 acc_train_loss 69.52 acc_train_error 0.30% test_error 16.20%
# 887 acc_train_loss 69.92 acc_train_error 0.40% test_error 15.80%
# 888 acc_train_loss 69.74 acc_train_error 0.30% test_error 15.90%
# 889 acc_train_loss 70.53 acc_train_error 0.40% test_error 15.80%
# 890 acc_train_loss 70.74 acc_train_error 0.30% test_error 16.10%
# 891 acc_train_loss 71.94 acc_train_error 0.40% test_error 15.70%
# 892 acc_train_loss 72.53 acc_train_error 0.30% test_error 16.40%
# 893 acc_train_loss 74.10 acc_train_error 0.40% test_error 15.70%
# 894 acc_train_loss 75.00 acc_train_error 0.30% test_error 16.50%
# 895 acc_train_loss 76.80 acc_train_error 0.40% test_error 15.60%
# 896 acc_train_loss 77.85 acc_train_error 0.30% test_error 16.30%
# 897 acc_train_loss 79.57 acc_train_error 0.40% test_error 15.50%
# 898 acc_train_loss 80.41 acc_train_error 0.30% test_error 16.10%
# 899 acc_train_loss 81.62 acc_train_error 0.40% test_error 15.50%
# 900 acc_train_loss 81.87 acc_train_error 0.30% test_error 15.90%
# 901 acc_train_loss 82.21 acc_train_error 0.40% test_error 15.50%
# 902 acc_train_loss 81.66 acc_train_error 0.30% test_error 15.90%
# 903 acc_train_loss 81.07 acc_train_error 0.40% test_error 15.40%
# 904 acc_train_loss 79.83 acc_train_error 0.40% test_error 15.90%
# 905 acc_train_loss 78.61 acc_train_error 0.40% test_error 15.30%
# 906 acc_train_loss 77.02 acc_train_error 0.40% test_error 15.90%
# 907 acc_train_loss 75.58 acc_train_error 0.30% test_error 15.20%
# 908 acc_train_loss 74.00 acc_train_error 0.30% test_error 15.90%
# 909 acc_train_loss 72.68 acc_train_error 0.40% test_error 15.10%
# 910 acc_train_loss 71.35 acc_train_error 0.30% test_error 15.80%
# 911 acc_train_loss 70.32 acc_train_error 0.40% test_error 15.20%
# 912 acc_train_loss 69.34 acc_train_error 0.30% test_error 16.00%
# 913 acc_train_loss 68.66 acc_train_error 0.40% test_error 15.10%
# 914 acc_train_loss 68.08 acc_train_error 0.30% test_error 16.00%
# 915 acc_train_loss 67.76 acc_train_error 0.40% test_error 15.10%
# 916 acc_train_loss 67.62 acc_train_error 0.30% test_error 16.10%
# 917 acc_train_loss 67.72 acc_train_error 0.40% test_error 15.20%
# 918 acc_train_loss 68.09 acc_train_error 0.30% test_error 16.30%
# 919 acc_train_loss 68.72 acc_train_error 0.30% test_error 15.00%
# 920 acc_train_loss 69.73 acc_train_error 0.30% test_error 16.20%
# 921 acc_train_loss 71.07 acc_train_error 0.30% test_error 15.00%
# 922 acc_train_loss 72.86 acc_train_error 0.60% test_error 16.50%
# 923 acc_train_loss 75.08 acc_train_error 0.30% test_error 15.10%
# 924 acc_train_loss 77.61 acc_train_error 0.60% test_error 16.60%
# 925 acc_train_loss 80.59 acc_train_error 0.30% test_error 15.00%
# 926 acc_train_loss 83.23 acc_train_error 0.60% test_error 16.80%
# 927 acc_train_loss 86.13 acc_train_error 0.30% test_error 14.80%
# 928 acc_train_loss 87.55 acc_train_error 0.70% test_error 16.40%
# 929 acc_train_loss 88.98 acc_train_error 0.40% test_error 14.90%
# 930 acc_train_loss 88.14 acc_train_error 0.60% test_error 16.40%
# 931 acc_train_loss 87.49 acc_train_error 0.40% test_error 15.00%
# 932 acc_train_loss 84.83 acc_train_error 0.60% test_error 16.50%
# 933 acc_train_loss 82.86 acc_train_error 0.30% test_error 15.20%
# 934 acc_train_loss 79.71 acc_train_error 0.50% test_error 16.40%
# 935 acc_train_loss 77.59 acc_train_error 0.20% test_error 15.20%
# 936 acc_train_loss 74.92 acc_train_error 0.50% test_error 16.50%
# 937 acc_train_loss 73.31 acc_train_error 0.20% test_error 15.00%
# 938 acc_train_loss 71.45 acc_train_error 0.50% test_error 16.30%
# 939 acc_train_loss 70.55 acc_train_error 0.30% test_error 15.10%
# 940 acc_train_loss 69.49 acc_train_error 0.30% test_error 16.40%
# 941 acc_train_loss 69.29 acc_train_error 0.30% test_error 15.30%
# 942 acc_train_loss 68.97 acc_train_error 0.30% test_error 16.40%
# 943 acc_train_loss 69.47 acc_train_error 0.40% test_error 15.60%
# 944 acc_train_loss 69.90 acc_train_error 0.30% test_error 16.10%
# 945 acc_train_loss 71.16 acc_train_error 0.40% test_error 15.60%
# 946 acc_train_loss 72.37 acc_train_error 0.30% test_error 15.90%
# 947 acc_train_loss 74.48 acc_train_error 0.40% test_error 15.60%
# 948 acc_train_loss 76.47 acc_train_error 0.30% test_error 16.00%
# 949 acc_train_loss 79.36 acc_train_error 0.30% test_error 15.90%
# 950 acc_train_loss 81.86 acc_train_error 0.20% test_error 15.80%
# 951 acc_train_loss 85.09 acc_train_error 0.30% test_error 15.80%
# 952 acc_train_loss 87.28 acc_train_error 0.20% test_error 15.90%
# 953 acc_train_loss 89.78 acc_train_error 0.30% test_error 16.00%
# 954 acc_train_loss 90.46 acc_train_error 0.30% test_error 15.80%
# 955 acc_train_loss 91.06 acc_train_error 0.30% test_error 16.10%
# 956 acc_train_loss 89.53 acc_train_error 0.30% test_error 15.80%
# 957 acc_train_loss 87.96 acc_train_error 0.30% test_error 16.30%
# 958 acc_train_loss 84.82 acc_train_error 0.20% test_error 15.50%
# 959 acc_train_loss 81.97 acc_train_error 0.30% test_error 16.40%
# 960 acc_train_loss 78.48 acc_train_error 0.20% test_error 15.40%
# 961 acc_train_loss 75.51 acc_train_error 0.20% test_error 16.60%
# 962 acc_train_loss 72.56 acc_train_error 0.20% test_error 15.10%
# 963 acc_train_loss 70.10 acc_train_error 0.20% test_error 16.70%
# 964 acc_train_loss 67.95 acc_train_error 0.20% test_error 15.10%
# 965 acc_train_loss 66.11 acc_train_error 0.20% test_error 16.50%
# 966 acc_train_loss 64.66 acc_train_error 0.20% test_error 15.40%
# 967 acc_train_loss 63.36 acc_train_error 0.10% test_error 16.50%
# 968 acc_train_loss 62.42 acc_train_error 0.20% test_error 15.40%
# 969 acc_train_loss 61.51 acc_train_error 0.10% test_error 16.50%
# 970 acc_train_loss 60.94 acc_train_error 0.20% test_error 15.50%
# 971 acc_train_loss 60.31 acc_train_error 0.10% test_error 16.50%
# 972 acc_train_loss 59.99 acc_train_error 0.20% test_error 15.50%
# 973 acc_train_loss 59.57 acc_train_error 0.10% test_error 16.50%
# 974 acc_train_loss 59.44 acc_train_error 0.20% test_error 15.50%
# 975 acc_train_loss 59.18 acc_train_error 0.10% test_error 16.50%
# 976 acc_train_loss 59.20 acc_train_error 0.20% test_error 15.50%
# 977 acc_train_loss 59.08 acc_train_error 0.10% test_error 16.50%
# 978 acc_train_loss 59.24 acc_train_error 0.20% test_error 15.50%
# 979 acc_train_loss 59.24 acc_train_error 0.10% test_error 16.50%
# 980 acc_train_loss 59.54 acc_train_error 0.20% test_error 15.40%
# 981 acc_train_loss 59.67 acc_train_error 0.10% test_error 16.60%
# 982 acc_train_loss 60.12 acc_train_error 0.20% test_error 15.40%
# 983 acc_train_loss 60.40 acc_train_error 0.10% test_error 16.60%
# 984 acc_train_loss 61.00 acc_train_error 0.20% test_error 15.40%
# 985 acc_train_loss 61.43 acc_train_error 0.10% test_error 16.60%
# 986 acc_train_loss 62.21 acc_train_error 0.20% test_error 15.40%
# 987 acc_train_loss 62.79 acc_train_error 0.10% test_error 16.80%
# 988 acc_train_loss 63.74 acc_train_error 0.20% test_error 15.30%
# 989 acc_train_loss 64.46 acc_train_error 0.10% test_error 16.80%
# 990 acc_train_loss 65.55 acc_train_error 0.20% test_error 15.30%
# 991 acc_train_loss 66.35 acc_train_error 0.10% test_error 16.70%
# 992 acc_train_loss 67.50 acc_train_error 0.20% test_error 15.40%
# 993 acc_train_loss 68.29 acc_train_error 0.10% test_error 16.60%
# 994 acc_train_loss 69.37 acc_train_error 0.20% test_error 15.40%
# 995 acc_train_loss 69.99 acc_train_error 0.10% test_error 16.70%
# 996 acc_train_loss 70.84 acc_train_error 0.30% test_error 15.50%
# 997 acc_train_loss 71.14 acc_train_error 0.10% test_error 16.90%
# 998 acc_train_loss 71.64 acc_train_error 0.30% test_error 15.60%
# 999 acc_train_loss 71.52 acc_train_error 0.10% test_error 16.80%

# %%
accuracy = 100-16.80
accuracy
# Out:
# 83.2

# %% [markdown]
# **Conclusion**
#
# We achieved $0.10\%$ training error and $16.80\%$ testing error.
#
# The accuracy is $83.2\%$
